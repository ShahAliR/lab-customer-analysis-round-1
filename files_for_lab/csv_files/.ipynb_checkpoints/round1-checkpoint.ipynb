# %% [markdown]
# Round1

# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')
print(file1.shape, file2.shape, file3.shape)

display(file1.head())
 
display(file2.head())
 
display(file3.head())
# Out:
# (4008, 11) (996, 11) (7070, 11)
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
# ...

# %%
column_names = file1.columns
column_names
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
# Header = pd.DataFrame(columns=column_names)
# Header

# %%
cols1 = []
for colname in file1.columns:
    cols1.append(colname.lower())
file1.columns = cols1
 
cols2 = []
for colname in file2.columns:
    cols2.append(colname.lower())
file2.columns = cols2
   

cols3 = []
for colname in file3.columns:
    cols3.append(colname.lower())
file3.columns = cols3

file3 = file3.rename(columns={'state':'st',})

print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')
# Index(['customer', 'st', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
allinone = pd.concat([file1,file2,file3], axis=0)
allinone
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
allinone['customer lifetime value'] = allinone['customer lifetime value'].str.replace('%', '')
allinone 
allinone['customer lifetime value'] =  pd.to_numeric(allinone['customer lifetime value'], errors='coerce')

# %%
allinone.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
numerics = ['float64']
allinone.select_dtypes(include=numerics)
# Out:
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18      0.0                 106.0
# 4                   536307.65  36357.0                  68.0
# ...                       ...      ...                   ...
# 7065                      NaN  71941.0                  73.0
# 7066                      NaN  21604.0                  79.0
# 7067                      NaN      0.0                  85.0
# 7068                      NaN  21941.0                  96.0
# 7069                      NaN      0.0                  77.0
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# ...

# %%
categorical = ['object']
allinone.select_dtypes(include=categorical)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      number of open complaints     policy type  vehicle class
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# ...

# %%
round(allinone.isna().sum()/len(allinone),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(allinone.isna().sum()/len(allinone),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                    customer          24.32
# 1                          st          24.32
# 2                      gender          25.34
# 3                   education          24.32
# 4     customer lifetime value          82.94
# 5                      income          24.32
# 6        monthly premium auto          24.32
# 7   number of open complaints          24.32
# 8                 policy type          24.32
# 9               vehicle class          24.32
# 10         total claim amount          24.32

# %%
allinone.shape
# Out:
# (12074, 11)

# %%
allinone = allinone.drop_duplicates()
allinone.isna().sum()
# Out:
# customer                        1
# st                              1
# gender                        123
# education                       1
# customer lifetime value      7078
# income                          1
# monthly premium auto            1
# number of open complaints       1
# policy type                     1
# vehicle class                   1
# total claim amount              1
# dtype: int64

# %%
# allinone.gender.unique()

# %%
allinone=allinone.dropna()
allinone.isna().sum()
# Out:
# customer                     0
# st                           0
# gender                       0
# education                    0
# customer lifetime value      0
# income                       0
# monthly premium auto         0
# number of open complaints    0
# policy type                  0
# vehicle class                0
# total claim amount           0
# dtype: int64

# %%
allinone.drop(['education','number of open complaints' ], axis=1)# drop education and number of open complaints
# Out:
#     customer          st gender  customer lifetime value   income  \
# 1    QZ44356     Arizona      F                697953.59      0.0
# 2    AI49188      Nevada      F               1288743.17  48767.0
# 3    WW63253  California      M                764586.18      0.0
# 4    GA49547  Washington      M                536307.65  36357.0
# 5    OC83172      Oregon      F                825629.78  62902.0
# ..       ...         ...    ...                      ...      ...
# 991  HV85198     Arizona      M                847141.75  63513.0
# 992  BS91566     Arizona      F                543121.91  58161.0
# 993  IL40123      Nevada      F                568964.41  83640.0
# 994  MY32149  California      F                368672.38      0.0
# 995  SA91515  California      M                399258.39      0.0
#
#      monthly premium auto     policy type  vehicle class  total claim amount
# 1                    94.0   Personal Auto  Four-Door Car         1131.464935
# ...

# %%
# allinone.loc[:,['customer', 'st', 'gender', 'customer lifetime value',
#        'income', 'monthly premium auto',
#        'policy type', 'vehicle class', 'total claim amount'
#        ]] #alternative for privious

# %%
# allinone[['customer', 'st', 'gender', 'customer lifetime value',
#        'income', 'monthly premium auto',
#        'policy type', 'vehicle class', 'total claim amount', 'state',
#        'gender']]
# Out:
#      customer          st gender gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F    NaN              697953.59%      0.0
# 2     AI49188      Nevada      F    NaN             1288743.17%  48767.0
# 3     WW63253  California      M    NaN              764586.18%      0.0
# 4     GA49547  Washington      M    NaN              536307.65%  36357.0
# ...       ...         ...    ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN      M             23405.98798  71941.0
# 7066  PK87824         NaN    NaN      F             3096.511217  21604.0
# 7067  TD14365         NaN    NaN      M             8163.890428      0.0
# 7068  UP19263         NaN    NaN      M             7524.442436  21941.0
# 7069  Y167826         NaN    NaN      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# ...

# %%
 
allinone['having_income'] = allinone['income']>0
 
allinone
# Out:
#     customer          st gender             education  \
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# 5    OC83172      Oregon      F              Bachelor
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...

# %%
allinone[allinone['having_income']==True]
# Out:
#     customer          st gender             education  \
# 2    AI49188      Nevada      F              Bachelor
# 4    GA49547  Washington      M  High School or Below
# 5    OC83172      Oregon      F              Bachelor
# 6    XZ87318      Oregon      F               College
# 8    DY87989      Oregon      M              Bachelor
# ..       ...         ...    ...                   ...
# 988  EX61844     Arizona      M  High School or Below
# 989  QC30857      Nevada      F               College
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
#
#      customer lifetime value   income  monthly premium auto  \
# 2                 1288743.17  48767.0                 108.0
# 4                  536307.65  36357.0                  68.0
# 5                  825629.78  62902.0                  69.0
# 6                  538089.86  55350.0                  67.0
# ...
